# %%
import matplotlib.pyplot as  plt
import numpy as np

# %%
x= np.linspace(0,5,11)
y=x**2

# %%
#Creando subplots
plt.subplot(1,3,1) #Los primeros 2 parámetros me indican la forma del arreglo
plt.plot(x,y)
plt.subplot(1,3,2)
plt.hist(y)
plt.subplot(1,3,3)
plt.pie(x)
plt.show()
