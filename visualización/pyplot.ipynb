# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
plt.plot(x,y)
plt.show()

# %%
#Agregando variaciones en la gráfica
plt.plot(x,y,"rs-")
plt.show()

# %%
plt.hist(y)
plt.show()
